# %% [markdown]
# <a href="https://colab.research.google.com/github/JayarajVp/coll_pro/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/shadow2496/VITON-HD.git
# Out:
# Cloning into 'VITON-HD'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 52 (delta 12), reused 6 (delta 6), pack-reused 33 (from 3)
# Receiving objects: 100% (52/52), 5.03 MiB | 26.98 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
cd VITON-HD
# Out:
# /content/VITON-HD

# %%
pip install opencv-python torchgeometry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 45.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import gdown

url = 'https://drive.google.com/uc?id=1cAUuGnK1jY_69YQuaqIJ2EJLL5bLYKVN'
output = 'checkpoints/alias_final.pth'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1cAUuGnK1jY_69YQuaqIJ2EJLL5bLYKVN
# From (redirected): https://drive.google.com/uc?id=1cAUuGnK1jY_69YQuaqIJ2EJLL5bLYKVN&confirm=t&uuid=c7490301-36e3-41c7-88b6-6669f0059a45
# To: /content/VITON-HD/checkpoints/alias_final.pth
# 100%|██████████| 402M/402M [00:04<00:00, 91.8MB/s]
# 'checkpoints/alias_final.pth'

# %%
import gdown

url = 'https://drive.google.com/uc?id=1W8teZFz_I4wZCasTQIsGa6el1HB4Vw8b'
output = 'checkpoints/gmm_final.pth'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1W8teZFz_I4wZCasTQIsGa6el1HB4Vw8b
# To: /content/VITON-HD/checkpoints/gmm_final.pth
# 100%|██████████| 76.2M/76.2M [00:00<00:00, 161MB/s]
# 'checkpoints/gmm_final.pth'

# %%
import gdown

url = 'https://drive.google.com/uc?id=1Nai8ladjicPGrXGHDFxrGo-u2iSsAWSV'
output = 'checkpoints/seg_final.pth'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Nai8ladjicPGrXGHDFxrGo-u2iSsAWSV
# From (redirected): https://drive.google.com/uc?id=1Nai8ladjicPGrXGHDFxrGo-u2iSsAWSV&confirm=t&uuid=30813c8d-e58b-4513-93f5-0467088c18f9
# To: /content/VITON-HD/checkpoints/seg_final.pth
# 100%|██████████| 138M/138M [00:01<00:00, 137MB/s]
# 'checkpoints/seg_final.pth'

# %%
import gdown

url = 'https://drive.google.com/uc?id=1CjHDBaP33hGNiCPH-8IiQNEdL1AQBCQn'
output = 'datasets/test_pairs.txt'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CjHDBaP33hGNiCPH-8IiQNEdL1AQBCQn
# To: /content/VITON-HD/datasets/test_pairs.txt
# 100%|██████████| 156/156 [00:00<00:00, 432kB/s]
# 'datasets/test_pairs.txt'

# %%
import gdown

url = 'https://drive.google.com/uc?id=1KKoaWoMxgSQxcMFNvUiFgMgGO3erz7lm'
output = 'datasets/test.zip'
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1KKoaWoMxgSQxcMFNvUiFgMgGO3erz7lm
# To: /content/VITON-HD/datasets/test.zip
# 100%|██████████| 2.69M/2.69M [00:00<00:00, 224MB/s]
# 'datasets/test.zip'

# %%
# !unzip datasets/test.zip -d datasets
# Out:
# Archive:  datasets/test.zip
#    creating: datasets/test/
#    creating: datasets/test/cloth/
#   inflating: datasets/test/cloth/02783_00.jpg
#   inflating: datasets/test/cloth/07429_00.jpg
#   inflating: datasets/test/cloth/11028_00.jpg
#   inflating: datasets/test/cloth/11351_00.jpg
#   inflating: datasets/test/cloth/01430_00.jpg
#   inflating: datasets/test/cloth/03751_00.jpg
#   inflating: datasets/test/cloth/06802_00.jpg
#   inflating: datasets/test/cloth/08348_00.jpg
#   inflating: datasets/test/cloth/09933_00.jpg
#   inflating: datasets/test/cloth/06429_00.jpg
#   inflating: datasets/test/cloth/11791_00.jpg
#   inflating: datasets/test/cloth/01260_00.jpg
#    creating: datasets/test/cloth-mask/
#   inflating: datasets/test/cloth-mask/02783_00.jpg
#   inflating: datasets/test/cloth-mask/07429_00.jpg
#   inflating: datasets/test/cloth-mask/11028_00.jpg
#   inflating: datasets/test/cloth-mask/11351_00.jpg
#   inflating: datasets/test/cloth-mask/01430_00.jpg
# ...

# %%
CUDA_VISIBLE_DEVICES=0

# %%
# !python test.py --name testiii
# Out:
# Namespace(name='testiii', batch_size=1, workers=1, load_height=1024, load_width=768, shuffle=False, dataset_dir='./datasets/', dataset_mode='test', dataset_list='test_pairs.txt', checkpoint_dir='./checkpoints/', save_dir='./results/', display_freq=1, seg_checkpoint='seg_final.pth', gmm_checkpoint='gmm_final.pth', alias_checkpoint='alias_final.pth', semantic_nc=13, init_type='xavier', init_variance=0.02, grid_size=5, norm_G='spectralaliasinstance', ngf=64, num_upsampling_layers='most')
# Network [SegGenerator] was created. Total number of parameters: 34.5 million. To see the architecture, do print(network).
# Network [ALIASGenerator] was created. Total number of parameters: 100.5 million. To see the architecture, do print(network).
# ...

# %%
ls results/testiii/
# Out:
# 00891_01430_00.jpg  07445_06429_00.jpg  08909_02783_00.jpg
# 03615_09933_00.jpg  07573_11791_00.jpg  10549_01260_00.jpg

# %%
from PIL import Image
#Image.open("results/testiii/00891_01430_00.jpg")
#Image.open("results/testiii/07445_06429_00.jpg")
#Image.open("results/testiii/08909_02783_00.jpg")
#Image.open("results/testiii/03615_09933_00.jpg")
Image.open("results/testiii/07573_11791_00.jpg")
#Image.open("results/testiii/10549_01260_00.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024>

# %%
from PIL import Image
#Image.open("results/testiii/00891_01430_00.jpg")
#Image.open("results/testiii/07445_06429_00.jpg")
#Image.open("results/testiii/08909_02783_00.jpg")
Image.open("results/testiii/03615_09933_00.jpg")
#Image.open("results/testiii/07573_11791_00.jpg")
#Image.open("results/testiii/10549_01260_00.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x1024>
